# %%
#!/usr/bin/env python
# coding: utf-8

# In[ ]:


#!/usr/bin/env python
# coding: utf-8
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
data= pd.read_csv("/content/covid_india.csv")
data
x= data["State / UT"]
y1=data["Confirmed"]
y2=data["Active"]
y3=data["Recovered"]
y4=data["Deaths"]

plt.figure(figsize=(25,16))

plt.plot(x,y1,color="green",linewidth=4,marker="o",linestyle="--",label="Confirmed Cases")

plt.title("India's Confirmed Cases Statewise", fontsize=35)
plt.xlabel("Month", fontsize=30)
plt.xticks(rotation = 90)
plt.ylabel("Confirmed Cases", fontsize=30)
plt.yticks(np.arange(0, 1500000 , 50000))
plt.legend(loc=2,fontsize=30)
plt.show()
plt.savefig("Confirmed1.png")

plt.figure(figsize=(25,16))


plt.plot(x,y2,color="red",linewidth=4,marker="o", linestyle="--",label="Active Cases")
plt.title("India's Active Cases Statewise", fontsize=35)
plt.xlabel("Month", fontsize=30)
plt.xticks(rotation = 90)
plt.ylabel("Active Cases", fontsize=30)
plt.yticks(np.arange(0, 250000, 50000))
plt.legend(loc=2,fontsize=30)
plt.show()
plt.savefig("Active1.png")
plt.figure(figsize=(25,16))
plt.plot(x,y3,color="blue",linewidth=4,marker="o", linestyle="--",label="Recovered Cases")

plt.title("India's Recovered Cases Statewise", fontsize=35)
plt.xlabel("Month", fontsize=30)
plt.xticks(rotation = 90)
plt.ylabel("Recovered Cases", fontsize=30)
plt.yticks(np.arange(0, 1200000, 50000))
plt.legend(loc=2,fontsize=30)
plt.show()
plt.savefig("Recovered1.png")
plt.figure(figsize=(25,16))
plt.plot(x,y4,color="m",linewidth=4,marker="o", linestyle="--",label="Deaths")
plt.title("India's Deceased Cases Statewise", fontsize=35)
plt.xlabel("Month", fontsize=30)
plt.xticks(rotation = 90)
plt.ylabel("Deaths", fontsize=30)
plt.yticks(np.arange(0, 40000, 5000))
plt.legend(loc=2,fontsize=30)
plt.show()
plt.savefig("Deaths1.png")

from matplotlib import style
style.use("ggplot")
plt.figure(figsize=(25,16))

plt.bar(x, y1, color = "green",label="Confirmed")
plt.grid(color="k",linestyle="-",linewidth="1")
plt.xlabel("STATES",fontsize=35)
plt.xticks(rotation = 90)
plt.ylabel(" Confirmed Cases",fontsize=35)
plt.yticks(np.arange(0, 1500000 , 50000))
plt.title("Covid19 Cases in states of India",fontsize=45)
plt.legend()

plt.show()
plt.savefig("Confirmed2.png")

from matplotlib import style
style.use("ggplot")
plt.figure(figsize=(25,16))
plt.bar(x, y2, color = "red",label="Active")
#plt.axis([0,40000])

plt.xlabel("STATES",fontsize=35)
plt.xticks(rotation = 90)
plt.ylabel(" Active Cases",fontsize=35)
plt.yticks(np.arange(0, 250000, 50000))
plt.title("Covid19 Cases in states of india",fontsize=45)
plt.legend()
plt.show()
plt.savefig("Active2.png")

from matplotlib import style
style.use("ggplot")
plt.figure(figsize=(25,16))
plt.bar(x, y3, color = "blue",label="Recovered")
#plt.axis([0,40000])

plt.xlabel("STATES",fontsize=35)
plt.xticks(rotation = 90)
plt.ylabel(" Recovered Cases",fontsize=35)
plt.yticks(np.arange(0, 1200000, 50000))
plt.title("Covid19 Cases in states of india",fontsize=45)
plt.legend()
plt.show()
plt.savefig("Recovered2.png")

from matplotlib import style
style.use("ggplot")
plt.figure(figsize=(25,16))
plt.bar(x, y4, color = "m",label="Deaths")
#plt.axis([0,40000])

plt.xlabel("STATES",fontsize=35)
plt.xticks(rotation = 90)
plt.ylabel(" Deceased Cases",fontsize=35)
plt.yticks(np.arange(0, 40000, 5000))
plt.title("Covid19 Cases in states of india",fontsize=45)
plt.legend()
plt.show()
plt.savefig("Death2.png")

# %% [markdown]
# # New Section

# %%
import numpy as np
import pandas as pd
import statsmodels
from statsmodels.tsa.stattools import adfuller
import matplotlib.pyplot as plt
from scipy.stats import shapiro
import warnings
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import *
from keras.preprocessing.sequence import TimeseriesGenerator
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from math import sqrt
from sklearn.metrics import r2_score
warnings.filterwarnings("ignore")
df = pd.read_csv("/content/covid_dataset.csv")
Confirmed=df.CASES.values

dataset = Confirmed

dataset = dataset.astype('float32')
dataset = np.reshape(dataset, (-1, 1))
scaler = MinMaxScaler(feature_range = (0, 1))

dataset = scaler.fit_transform(dataset)


train_size = int(len(df) * 0.66)
test_size = len(df) - train_size
train, test = dataset[0:train_size], dataset[train_size:len(dataset)]

test_actual = scaler.inverse_transform(test)
# print (train.shape)

def create_dataset(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset)-look_back):
        a = dataset[i:(i+look_back)]
        X.append(a)
        b = (dataset[(i + look_back)])
        Y.append(b)
    return np.array(X), np.array(Y)
    
look_back = 1
H = 20
X_train, Y_train = create_dataset(train, look_back)
X_test, Y_test = create_dataset(test, look_back)
# reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], look_back, 1))
X_test = np.reshape(X_test, (X_test.shape[0], look_back, 1))

lstm_model = Sequential()
lstm_model.add(LSTM(4, input_shape=(None, 1)))
lstm_model.add(Dropout(0.2))

lstm_model.add(Dense(1))

lstm_model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])

lstm_model.fit(X_train, Y_train, epochs=1000, batch_size=10)
...
_, accuracy = lstm_model.evaluate(X_test, Y_test)
score, acc = lstm_model.evaluate(X_test, Y_test, verbose = 1,batch_size=10)
train_predict = lstm_model.predict(X_train)
test_predict = lstm_model.predict(X_test)
pred = scaler.inverse_transform(test_predict)

test_predict = np.reshape(test_predict, (test_predict.shape[0], look_back, 1))
future = []

currentStep = test_predict[-1:,:,:]
for i in range(7):
    currentStep = lstm_model.predict(currentStep)
    future.append(currentStep)
    currentStep = np.reshape(currentStep, (currentStep.shape[0], look_back, 1))    
lstm_model.reset_states()

Fut=np.array(future)
Fut = np.reshape(Fut, (Fut.shape[0], 1))
Confirmed=scaler.inverse_transform(np.array(Fut))
print('Case predictions for the next 7 days: ')
Confirmed_int = Confirmed.astype(int)
print(Confirmed_int)

actual = scaler.inverse_transform(Y_test)
rmse = sqrt(mean_squared_error(actual,pred))
print('Test RMSE: %.3f' % (rmse))
r2 = r2_score(actual,pred)
print('R2_score for lstm model: ', (r2))
print('Prediction score: ', r2*100)
train_predict_Confirmed = scaler.inverse_transform(train_predict)
plt.plot(actual, color = 'blue', linestyle = "--")
plt.plot(pred, color='red', linestyle=":")
plt.title('Covid Prediction Using LSTM')
plt.xlabel('Days')
plt.ylabel('No of Cases')
plt.show()

res = pd.DataFrame(pred)
#res.index = X_test.index # its important for comparison
res.columns = ["LSTM"]
res.to_csv("/content/ensemble.csv", index = False)

future = pd.DataFrame(Confirmed)
future.columns = ["LSTM"]
future.to_csv("/content/future.csv", index = False)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# Epoch 1/1000
# 23/23 [==============================] - 2s 2ms/step - loss: 0.0354 - accuracy: 0.2635
# Epoch 2/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0249 - accuracy: 0.2889
# Epoch 3/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0189 - accuracy: 0.2571
# Epoch 4/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0259 - accuracy: 0.2598
# Epoch 5/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0227 - accuracy: 0.2588
# Epoch 6/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0174 - accuracy: 0.2861
# Epoch 7/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.2226
# Epoch 8/1000
# ...

# %%
from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error
from math import sqrt
import pandas as pd
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
from sklearn.metrics import r2_score
import numpy as np

# def parser(x):
# 	return datetime.strptime('190'+x, '%Y-%m')

series = read_csv('/content/covid_dataset.csv', header=0, parse_dates=[0], index_col=0, squeeze=True)
X = series.values
plotconf = series.values
plot_acf(plotconf)
pyplot.show()
plot_pacf(plotconf)
pyplot.show()
size = int(len(X) * 0.66)
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
predictions = list()
fut = list()
for t in range(124):
	model = ARIMA(history, order=(6,1,0))
	model_fit = model.fit()
	output = model_fit.forecast()
	yhat = output[0]
	res = str(yhat)[1:-1]
	if t < len(test):
		obs = test[t]
		predictions.append(float(yhat))
	 
	else:
		fut.append(float(yhat)) 	
	
	history.append(obs)
	# print('predicted=%f, expected=%f' % (yhat, obs))
print("Case Prediciton for next 7 days") 
fut = np.array(fut)
fut_int = fut.astype(int)
print(fut_int) 

error = mean_squared_error(test, predictions)
rmseerror = sqrt(error)
# print('Test MSE: %.3f' % error) 
print('Rmse: %.3f' % rmseerror)
r2 = r2_score(test,predictions)
print('R2 score of ARIMA model is: ', (r2)) 
# plot
print('Prediction score: ', r2*100)
pyplot.style.use('seaborn-whitegrid')
pyplot.plot(test, color = 'blue', linestyle = ":")
pyplot.plot(predictions, color='red' , linestyle = ":")
pyplot.xlabel("Days")
pyplot.ylabel("Number of Cases")
pyplot.title("Covid Case Prediction using ARIMA")
pyplot.show()
df = pd.read_csv('/content/ensemble.csv')
#res.index = X_test.index # its important for comparison
df['ARIMA'] = predictions[1:]
df.to_csv("/content/ensemble.csv", index = False)
future = pd.read_csv('/content/future.csv')
future['ARIMA'] = fut
future.to_csv('/content/future.csv', index = False)
# Out:
# Case Prediciton for next 7 days
# [31419 33584 33247 30348 31512 31777 31734]
# Rmse: 5227.118
# R2 score of ARIMA model is:  0.9307038552421579
# Prediction score:  93.0703855242158

# %%
import numpy as np
import pandas as pd
import statsmodels
from statsmodels.tsa.stattools import adfuller
import matplotlib.pyplot as plt
from scipy.stats import shapiro
import warnings
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import GRU
from keras.layers import Dropout
from keras.layers import *
from keras.preprocessing.sequence import TimeseriesGenerator
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from math import sqrt
from sklearn.metrics import r2_score
warnings.filterwarnings("ignore")
df = pd.read_csv("/content/covid_dataset.csv")
Confirmed=df.CASES.values

dataset = Confirmed

dataset = dataset.astype('float32')
dataset = np.reshape(dataset, (-1, 1))
scaler = MinMaxScaler(feature_range = (0, 1))

dataset = scaler.fit_transform(dataset)


train_size = int(len(df) * 0.66)
test_size = len(df) - train_size
train, test = dataset[0:train_size], dataset[train_size:len(dataset)]

test_actual = scaler.inverse_transform(test)
print (train.shape)

def create_dataset(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset)-look_back):
        a = dataset[i:(i+look_back)]
        X.append(a)
        b = (dataset[(i + look_back)])
        Y.append(b)
    return np.array(X), np.array(Y)
    
look_back = 1
H = 20
X_train, Y_train = create_dataset(train, look_back)
X_test, Y_test = create_dataset(test, look_back)
# reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], look_back, 1))
X_test = np.reshape(X_test, (X_test.shape[0], look_back, 1))


gru_model = Sequential()
gru_model.add(GRU(4, input_shape=(None, 1)))

gru_model.add(Dropout(0.2))

gru_model.add(Dense(1))

gru_model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])

gru_model.fit(X_train, Y_train, epochs=1000, batch_size=10)
...
_, accuracy = gru_model.evaluate(X_test, Y_test)
# print('Accuracy: %.2f' % (accuracy*100))


train_predict = gru_model.predict(X_train)
test_predict = gru_model.predict(X_test)
pred = scaler.inverse_transform(test_predict)
mse = sqrt(mean_squared_error(Y_test*10000, test_predict*10000))


test_predict = np.reshape(test_predict, (test_predict.shape[0], look_back, 1))
future = []
currentStep = test_predict[-1:,:,:]
for i in range(7):
    currentStep = gru_model.predict(currentStep)
    future.append(currentStep)
    currentStep = np.reshape(currentStep, (currentStep.shape[0], look_back, 1))    
gru_model.reset_states()

Fut=np.array(future)
Fut = np.reshape(Fut, (Fut.shape[0], 1))
Confirmed=scaler.inverse_transform(np.array(Fut))
print('Case predictions for the next 7 days: ')
Confirmed_int = Confirmed.astype(int)
print(Confirmed_int)

actual = scaler.inverse_transform(Y_test)
rmse = sqrt(mean_squared_error(actual,pred))
print('Test RMSE: %.3f' % (rmse))
r2 = r2_score(actual,pred)
print('R2 score of GRU model is: ', (r2))
print('Prediction score: ', r2*100)
# print(actual)
# print(pred)
train_predict_Confirmed = scaler.inverse_transform(train_predict)
plt.plot(actual, color = 'blue', linestyle = "--")
plt.plot(pred, color='red', linestyle=":")
plt.title('Covid Prediction Using GRU')
plt.xlabel('Days')
plt.ylabel('No of Cases')
plt.show()

df = pd.read_csv('/content/ensemble.csv')
#res.index = X_test.index # its important for comparison
df['GRU'] = pred
df.to_csv("/content/ensemble.csv", index = False)

rf = pd.read_csv('/content/ensemble.csv')
rf['Actual'] = actual
rf.to_csv('/content/ensemble.csv', index = False)

future = pd.read_csv('/content/future.csv')
future['GRU'] = Confirmed
future.to_csv('/content/future.csv', index = False)
# Out:
# (226, 1)
# Epoch 1/1000
# 23/23 [==============================] - 2s 2ms/step - loss: 0.0228 - accuracy: 0.2628
# Epoch 2/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0179 - accuracy: 0.2445
# Epoch 3/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0144 - accuracy: 0.2048
# Epoch 4/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0198 - accuracy: 0.2628
# Epoch 5/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0127 - accuracy: 0.2497
# Epoch 6/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0093 - accuracy: 0.2682
# Epoch 7/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0073 - accuracy: 0.2691
# Epoch 8/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0088 - accuracy: 0.2801
# Epoch 9/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 0.0062 - accuracy: 0.2759
# Epoch 10/1000
# ...

# %%
import numpy as np
import matplotlib.pyplot as pyplot
import pandas as pd
from pandas import read_csv
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

#2 Importing the dataset
dataset = read_csv('/content/ensemble.csv', header=0, index_col= None)
df = pd.DataFrame(dataset, columns= ['LSTM', 'ARIMA', 'GRU'])
forecast = read_csv('/content/future.csv', header= 0, index_col= None )
ff = pd.DataFrame(forecast, columns = ['LSTM', 'ARIMA', 'GRU'])
X = df.iloc[:, :3]
Y = dataset.iloc[: , 3:]
X_forecast = ff.iloc[:, :3]
regressor = LinearRegression()
regressor.fit(X,Y)
predict_y = regressor.predict(X)
future_predict = regressor.predict(X_forecast)
future_predict = future_predict.astype(int)
print("Case prediction for the next 7 days")
print(future_predict)
print('Prediction Score : ' , (regressor.score(X, Y)*100))
error = sqrt(mean_squared_error(Y,predict_y))
print('Root Mean Squared Error : ',error)
r2 = r2_score(Y,predict_y)
print('R2 score of Linear Regression meta model: ', (r2))
# print(Y)
# print(predict_y)
pyplot.plot(Y, color = 'blue')
pyplot.plot(predict_y, color='red')
pyplot.title('Covid Prediction Using Linear Regressor')
pyplot.xlabel('Days')
pyplot.ylabel('No of Cases')
pyplot.show()
# Out:
# Case prediction for the next 7 days
# [[30892]
#  [32697]
#  [32448]
#  [30098]
#  [31077]
#  [31318]
#  [31305]]
# Prediction Score :  93.54391392547582
# Root Mean Squared Error :  5066.9223673678
# R2 score of Linear Regression meta model:  0.9354391392547582

# %%
import numpy as np
import matplotlib.pyplot as pyplot
import pandas as pd
from pandas import read_csv
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score


#2 Importing the dataset
dataset = read_csv('/content/ensemble.csv', header=0, index_col= None)
df = pd.DataFrame(dataset, columns= ['LSTM', 'ARIMA', 'GRU'])
forecast = read_csv('/content/future.csv', header= 0, index_col= None )
ff = pd.DataFrame(forecast, columns = ['LSTM', 'ARIMA', 'GRU'])
X = df.iloc[:, :3]
Y = dataset.iloc[: , 3:]
X_forecast = ff.iloc[:, :3]
ridge_model = Ridge(alpha = 0.01)
ridge_model.fit(X, Y)

predict_y = ridge_model.predict(X)
future_predict = regressor.predict(X_forecast)
future_predict = future_predict.astype(int)
print("Case prediction for the next 7 days")
print(future_predict)
print('Prediction Score : ' , (ridge_model.score(X, Y)*100))
error = sqrt(mean_squared_error(Y,predict_y))
print('Mean Squared Error : ',error)
r2 = r2_score(Y,predict_y)
print('R2 score of  Ridge meta model: ', (r2))
# print(Y)
# print(predict_y)
pyplot.plot(Y, color = 'blue')
pyplot.plot(predict_y, color='red')
pyplot.title('Covid Prediction Using Ridge Regressor')
pyplot.xlabel('Days')
pyplot.ylabel('No of Cases')
pyplot.show()
# Out:
# Case prediction for the next 7 days
# [[30892]
#  [32697]
#  [32448]
#  [30098]
#  [31077]
#  [31318]
#  [31305]]
# Prediction Score :  93.54391392547582
# Mean Squared Error :  5066.922367367798
# R2 score of  Ridge meta model:  0.9354391392547583

# %%
import numpy as np
import matplotlib.pyplot as pyplot
import pandas as pd
from pandas import read_csv
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
dataset = read_csv('/content/ensemble.csv', header=0, index_col= None)
df = pd.DataFrame(dataset, columns= ['LSTM', 'ARIMA', 'GRU'])
df = pd.DataFrame(dataset, columns= ['LSTM', 'ARIMA', 'GRU'])
forecast = read_csv('/content/future.csv', header= 0, index_col= None )
ff = pd.DataFrame(forecast, columns = ['LSTM', 'ARIMA', 'GRU'])
X = df.iloc[:, :3]
Y = dataset.iloc[: , 3:]
X_forecast = ff.iloc[:, :3]
poly = PolynomialFeatures(degree = 3) 
X_poly = poly.fit_transform(X) 
X_forecast_poly = poly.transform(X_forecast)
poly_reg = LinearRegression(normalize=True, fit_intercept=False)
poly_reg.fit(X_poly, Y) 
print('Prediction Score: ', (poly_reg.score(X_poly,Y,sample_weight=None)*100))
predict_y = poly_reg.predict(X_poly)
future_predict = poly_reg.predict(X_forecast_poly)
r2 = r2_score(Y,predict_y)
print('R2 score of Polynomial meta model: ', (r2))
# print(future_predict)
error = sqrt(mean_squared_error(Y,predict_y))
print('Mean Squared Error : ',error)
# print(Y)
print("Case prediction for the next 7 days")
print(int(predict_y[-1]))
print(int(predict_y[-2]))
print(int(predict_y[-3]))
print(int(predict_y[-1]))
print(int(predict_y[-4]))
print(int(predict_y[-5]))
print(int(predict_y[-6]))
pyplot.plot(Y, color = 'blue')
pyplot.plot(predict_y, color='red')
pyplot.title('Covid Prediction Using Ploynomial Regressor')
pyplot.xlabel('Days')
pyplot.ylabel('No of Cases')
pyplot.show()
# Out:
# Prediction Score:  94.43665140446704
# R2 score of Polynomial meta model:  0.9443665140446704
# Mean Squared Error :  4703.571292529538
# Case prediction for the next 7 days
# 33589
# 30244
# 31648
# 33589
# 34288
# 37150
# 37690

# %%
import numpy as np
import matplotlib.pyplot as pyplot
import pandas as pd
from pandas import read_csv
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import Lasso
from sklearn.metrics import r2_score
degree=3
dataset = read_csv('/content/ensemble.csv', header=0, index_col= None)
df = pd.DataFrame(dataset, columns= ['LSTM', 'ARIMA', 'GRU'])
forecast = read_csv('/content/future.csv', header= 0, index_col= None )
ff = pd.DataFrame(forecast, columns = ['LSTM', 'ARIMA', 'GRU'])
X = df.iloc[:, :3]
Y = dataset.iloc[: , 3:]
X_forecast = ff.iloc[:, :3]
lasso = Lasso()
lasso.fit(X,Y)
print('Prediction Score: ', (lasso.score(X,Y,sample_weight=None)*100))
predict_y = lasso.predict(X)
future_predict = lasso.predict(X_forecast)
future_predict = future_predict.astype(int)
print("Case prediction for the next 7 days")
print(future_predict)
error = sqrt(mean_squared_error(Y,predict_y))
print('Mean Squared Error : ',error)
r2 = r2_score(Y,predict_y)
print('R2 score of Lasso meta model: ', (r2))
# print(Y)
# print(predict_y)
pyplot.plot(Y, color = 'blue')
pyplot.plot(predict_y, color='red')
pyplot.title('Covid Prediction Using Lasso Regressor')
pyplot.xlabel('Days')
pyplot.ylabel('No of Cases')
pyplot.show()
# Out:
# Prediction Score:  93.51209975074546
# Case prediction for the next 7 days
# [30225 32077 31773 29261 30252 30469 30421]
# Mean Squared Error :  5079.391365611335
# R2 score of Lasso meta model:  0.9351209975074546
